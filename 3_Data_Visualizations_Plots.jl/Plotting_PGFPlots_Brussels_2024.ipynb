# %%
using DataFrames, Plots, LaTeXStrings, PGFPlotsX
pgfplotsx() # this is a backend for LaTeX plotting
# Out:
# Plots.PGFPlotsXBackend()

# %%
df = DataFrame(y1=rand(5), y2=rand(5).+2)
# Out:
# 5×2 DataFrame
#  Row │ y1        y2
#      │ Float64   Float64
# ─────┼───────────────────
#    1 │ 0.773865  2.97536
#    2 │ 0.550251  2.67751
#    3 │ 0.454479  2.62669
#    4 │ 0.391891  2.42327
#    5 │ 0.14775   2.33622

# %%
p = plot(;xlabel=L"\hat{x}", ylabel=L"Some $y$ value", legend=:left )
plot!(p, df.y1, label=L"Y_1", linecolor=:blue,linewidth=2)
plot!(p, df.y2, label=L"Y_2", linecolor=:red,linewidth=3)

# %%
savefig(p,"myplt.tikz")
savefig(p,"myplt.pdf")
# Out:
# "C:\\AAABIBLIOTEKA\\CAMK\\2024_Julia_EC_EconomicDepShort\\3_Data_Visualizations_Plots.jl\\myplt.pdf"

# %%
latex=raw"""
\documentclass{article}
\usepackage{tikz} 
\usepackage{tikzscale}
\usepackage{pgfplots}
\usetikzlibrary{backgrounds}
\usetikzlibrary{intersections}

\begin{document}
\title{My Research for EC}
\maketitle
\section{Section}
text text text
\begin{figure}
\includegraphics[width=\textwidth]{myplt.tikz}
\caption{My caption}
\end{figure}
\end{document}
"""
open("example.tex","w") do f println(f, latex) end
pwd()
# Out:
# "C:\\AAABIBLIOTEKA\\CAMK\\2024_Julia_EC_EconomicDepShort\\3_Data_Visualizations_Plots.jl"
