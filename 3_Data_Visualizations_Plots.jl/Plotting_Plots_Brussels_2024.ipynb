# %%
using Plots
ENV["GKSwstype"]="nul"
Plots.gr()  # sellect plotting backend see https://docs.juliaplots.org/latest/backends/
# Out:
# Plots.GRBackend()

# %%
histogram2d(randn(10000), randn(10000), nbins=20)

# %%
plot(Plots.fakedata(50,5),w=3)
title!("SomeTitle")
xlabel!("Os X")
ylabel!("Os Y")
savefig(raw"c:\temp\myplot.pdf")
# Out:
# "c:\\temp\\myplot.pdf"

# %%
# Running an animation based on http://docs.juliaplots.org/latest/

using Plots
# define the Lorenz attractor
mutable struct Lorenz
    dt; σ; ρ; β; x; y; z
end

function step!(l::Lorenz)
    dx = l.σ*(l.y - l.x)       ; l.x += l.dt * dx
    dy = l.x*(l.ρ - l.z) - l.y ; l.y += l.dt * dy
    dz = l.x*l.y - l.β*l.z     ; l.z += l.dt * dz
end

attractor = Lorenz((dt = 0.02, σ = 10., ρ = 28., β = 8//3, x = 1., y = 1., z = 1.)...)


# initialize a 3D plot with 1 empty series
plt = plot3d(1, xlim=(-25,25), ylim=(-25,25), zlim=(0,50),
                title = "Lorenz Attractor", marker = 2)

# build an animated gif by pushing new points to the plot, saving every 20th frame
@gif for i=1:10000
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end every 20
# Out:
# [ Info: Saved animation to C:\AAABIBLIOTEKA\CAMK\2024_Julia_EC_EconomicDepShort\3_Data_Visualizations_Plots.jl\tmp.gif
# Plots.AnimatedGif("C:\\AAABIBLIOTEKA\\CAMK\\2024_Julia_EC_EconomicDepShort\\3_Data_Visualizations_Plots.jl\\tmp.gif")
